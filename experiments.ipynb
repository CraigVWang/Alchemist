# %%
from commander import Commander
import hydra
from omegaconf import OmegaConf

# Set the function to load and override config.
def load_config(overrides=[]):
    with hydra.initialize(version_base=None, config_path="./config/"):
        return hydra.compose(
            config_name="base.yaml", overrides=overrides
            )

conf = load_config(overrides=[])
print(OmegaConf.to_yaml(conf))

exp = Commander(conf=conf)
exp.run_preprocessor()
exp.run_provider()
# Out:
# data:
#   data_dir: ./data
#   input:
#     inputs_dir: ${data.data_dir}/inputs
#     raw_dir: ${data.input.inputs_dir}/raw
#   output:
#     outputs_dir: ${data.data_dir}/outputs
#     preprocessed_dir: ${data.output.outputs_dir}/preprocessed
#     prepared_systems_dir: ${data.output.outputs_dir}/prepared_systems
#     ligand_dir: ${data.output.preprocessed_dir}/ligands
#     protein_dir: ${data.output.preprocessed_dir}/proteins
#     alchemical_dir: ${data.output.outputs_dir}/alchemical_results
#     analysis_dir: ${data.output.outputs_dir}/analysis_results
#     visualization_dir: ${data.output.outputs_dir}/visualizations
#   experiments_dir: ${data.data_dir}/experiments
# metadata_admin:
#   metadata_dir: ${data.output.outputs_dir}/metadata
# converter: null
# preprocessor: null
# provider:
#   forcefield:
#     protein: amber14/protein.ff14SB.xml
#     ligand: GAFF
#     solvent: amber14/tip3p.xml
#   system:
#     add_hydrogens: true
#     nonbonded_method: PME
#     cutoff: 1.0
#     constraints: HBonds
#     rigid_water: true
#     ewald_error_tolerance: 0.0005
#     centering_threshold: 0.1
#   solvent:
#     model: tip3p
#     box_size: 8.0
#     padding: null
#     positive_ion: null
#     negative_ion: null
#     ionic_strength: null
#   integrator:
#     temperature: 300.0
#     friction_coeff: 1.0
#     time_step: 2.0
#   platform:
#     use_cuda: true
#     device_index: '0'
#     precision: mixed
#   minimization:
#     max_iterations: 1000
#     tolerance: 10.0
#   heating:
#     initial_temperature: 50.0
#     target_temperature: 300.0
#     temperature_step: 50.0
#     steps_per_temperature: 5000
#   equilibration:
#     use_barostat: true
#     pressure: 1.0
#     barostat_frequency: 25
#     npt_steps: 50000
# alchemist: null
# analyzer: null
# commander:
#   mode: test_single
# runner: null
#
# ========================================
# 🚀 开始数据预处理阶段
# ========================================
# ========================================
#
# 🔧 初始化预处理器...
# 📂 目录设置完成:
#    - 数据目录: ./data
#    - 输入处理目录: ./data/inputs
#    - 原始数据目录: ./data/inputs/raw
#    - 输出数据文件: ./data/outputs
#    - 预处理数据文件: ./data/outputs/preprocessed
#    - 系统数据文件: ./data/outputs/prepared_systems
#    - 配体分子文件: ./data/outputs/preprocessed/ligands
#    - 蛋白质文件: ./data/outputs/preprocessed/proteins
#    - 炼金术数据文件: ./data/outputs/alchemical_results
#    - 分析数据文件: ./data/outputs/analysis_results
#    - 可视化数据文件: ./data/outputs/visualizations
#    - 实验数据文件: ./data/experiments
#    - 元数据文件: ./data/outputs/metadata
# 📂 目录设置完成:
# ✅ 预处理器初始化成功!
#
# ========================================
# ========================================
# 🚀 开始结构文件预处理流程
# ========================================
# 📖 读取现有元数据文件: data/outputs/metadata/metadata.csv
# ========================================
# 🔍 处理所有支持格式的文件
# 📁 开始扫描目录: ./data/inputs/raw
# 📂 扫描文件: 100%|██████████| 14/14 [00:00<00:00, 74518.09it/s]
# ✅ 找到 7 个分子（7 个现有 + 0 个新）
# ========================================
#
# 🔄 开始批量处理文件...
# 🔄 处理文件: 100%|██████████| 7/7 [00:00<00:00, 2147.15it/s, 跳过: 0/7]
# 📊 成功处理 0/7 个文件
# 💾 元数据已保存到: data/outputs/metadata/metadata.csv
# ========================================
#
# 📈 文件类型统计:
#    - pdb: 1 个文件
#    - mol: 6 个文件
# 🔍 找到 1 个可能的PDB ID
#
# 📊 处理状态统计:
#    - 总分子数: 7
#    - 预处理成功: 7 (100.0%)
#    - 系统准备成功: 0 (0.0%)
#    - 炼金术成功: 0 (0.0%)
#    - 分析成功: 0 (0.0%)
#    - 完成全部流程: 0 (0.0%)
# ========================================
# 🎉 结构文件预处理完成!
# ========================================
# ========================================
# 🔄 运行系统准备模块...
# ========================================
# ============================================================
# 🚀 开始分子系统准备流程
# ⚙️ 使用配置:
#    - 盒子大小: 8.0 nm
#    - 溶剂模型: tip3p
#    - 温度: 300.0 K
#    - 时间步长: 2.0 fs
#    - 使用GPU: True
# ============================================================
# 📖 读取到 7 个分子信息
# 🔍 找到 7 个需要处理的分子
# 🔄 系统准备: 100%|██████████| 7/7 [00:00<00:00, 1839.72it/s, 成功: 0/7]
# ❌ 文件不存在: ('./data/outputs/preprocessed/proteins/PyAutoFep/receptor_data/5q17_processed.pdb', None)
#   📝 更新分子状态: 5q17_processed - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_74.mol', None)
#   📝 更新分子状态: FXR_74 - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_85.mol', None)
#   📝 更新分子状态: FXR_85 - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_76.mol', None)
#   📝 更新分子状态: FXR_76 - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_84.mol', None)
#   📝 更新分子状态: FXR_84 - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_88.mol', None)
#   📝 更新分子状态: FXR_88 - preparation = 失败
# ❌ 文件不存在: ('./data/outputs/preprocessed/ligands/PyAutoFep/lig_data/FXR_12.mol', None)
#   📝 更新分子状态: FXR_12 - preparation = 失败
#
# 📊 准备完成:
#    - 总处理: 7
#    - 成功准备: 0
#    - 成功率: 0.0%
# ⚠️ 警告：准备结果为空，跳过保存pickle文件
