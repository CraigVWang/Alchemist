# %%
from commander import Commander
import hydra
from omegaconf import OmegaConf

# Set the function to load and override config.
def load_config(overrides=[]):
    with hydra.initialize(version_base=None, config_path="./config/"):
        return hydra.compose(
            config_name="base.yaml", overrides=overrides
            )

conf = load_config(overrides=[])
print(OmegaConf.to_yaml(conf))

exp = Commander(conf=conf)
exp.run_preprocessor()
# Out:
# data:
#   data_dir: ./data
#   input:
#     inputs_dir: ${data_dir}/inputs
#     raw_dir: ${input.base_dir}/raw
#   output:
#     outputs_dir: ${data_dir}/outputs
#     preprocessed_dir: ${output.base_dir}/preprocessed
#     ligand_dir: ${output.preprocessed_dir}/ligands
#     protein_dir: ${output.preprocessed_dir}/proteins
#     alchemical_dir: ${output.base_dir}/alchemical_results
#     analysis_dir: ${output.base_dir}/analysis_results
#     visualization_dir: ${output.base_dir}/visualizations
#   experiments_dir: ${data_dir}/experiments
# metadata_admin:
#   metadata_dir: ${data.output.base_dir}/metadata
# converter: null
# preprocessor: 'N'
# provider:
#   ligand: null
#   receptor: null
#   solvent: null
# alchemist: null
# analyzer: null
# commander:
#   mode: test_single
# runner: null
#
# ========================================
# 🚀 开始数据预处理阶段
# ========================================
# ========================================
#
# 🔧 初始化预处理器...
# ---------------------------------------------------------------------------
# InterpolationKeyError                     Traceback (most recent call last)
# Cell In[1], line 16
#      13 print(OmegaConf.to_yaml(conf))
#      15 exp = Commander(conf=conf)
# ---> 16 exp.run_preprocessor()
#
# File ~/workspace/Alchemist/commander.py:50, in Commander.run_preprocessor(self, test_single)
#      47 print("="*40)
#      49 if self.preprocessor is None:
# ---> 50     self.preprocessor = Preprocessor(conf=self.conf)
#      52 result = self.preprocessor.run(test_single)
#      53 self.metadata = result['metadata']
#
# File ~/workspace/Alchemist/preprocessor.py:43, in Preprocessor.__init__(self, conf)
#      41 # 导入目录
#      42 self.data_dir = self.conf.data.data_dir
# ---> 43 self.inputs_dir = self.conf.data.input.inputs_dir
#      44 self.raw_dir = self.conf.data.input.raw_dir
#      45 self.outputs_dir = self.conf.data.output.outputs_dir
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/dictconfig.py:359, in DictConfig.__getattr__(self, key)
#     355     self._format_and_raise(
#     356         key=key, value=None, cause=e, type_override=ConfigAttributeError
#     357     )
#     358 except Exception as e:
# --> 359     self._format_and_raise(key=key, value=None, cause=e)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)    229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/dictconfig.py:351, in DictConfig.__getattr__(self, key)
#     348     raise AttributeError()
#     350 try:
# --> 351     return self._get_impl(
#     352         key=key, default_value=_DEFAULT_MARKER_, validate_key=False
#     353     )
#     354 except ConfigKeyError as e:
#     355     self._format_and_raise(
#     356         key=key, value=None, cause=e, type_override=ConfigAttributeError
#     357     )
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/dictconfig.py:451, in DictConfig._get_impl(self, key, default_value, validate_key)
#     449         raise
#     450 assert isinstance(node, Node)
# --> 451 return self._resolve_with_default(
#     452     key=key, value=node, default_value=default_value
#     453 )
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/basecontainer.py:98, in BaseContainer._resolve_with_default(self, key, value, default_value)
#      95         return default_value
#      96     raise MissingMandatoryValue("Missing mandatory value: $FULL_KEY")
# ---> 98 resolved_node = self._maybe_resolve_interpolation(
#      99     parent=self,
#     100     key=key,
#     101     value=value,
#     102     throw_on_resolution_failure=True,
#     103 )
#     105 return _get_value(resolved_node)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:719, in Container._maybe_resolve_interpolation(self, parent, key, value, throw_on_resolution_failure, memo)
#     716     return value
#     718 parse_tree = parse(_get_value(value))
# --> 719 return self._resolve_interpolation_from_parse_tree(
#     720     parent=parent,
#     721     value=value,
#     722     key=key,
#     723     parse_tree=parse_tree,
#     724     throw_on_resolution_failure=throw_on_resolution_failure,
#     725     memo=memo if memo is not None else set(),
#     726 )
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:584, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     554 """
#     555 Resolve an interpolation.
#     556
#    (...)    580     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     581 """
#     583 try:
# --> 584     resolved = self.resolve_parse_tree(
#     585         parse_tree=parse_tree, node=value, key=key, memo=memo
#     586     )
#     587 except InterpolationResolutionError:
#     588     if throw_on_resolution_failure:
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:764, in Container.resolve_parse_tree(self, parse_tree, node, memo, key)
#     758 visitor = GrammarVisitor(
#     759     node_interpolation_callback=node_interpolation_callback,
#     760     resolver_interpolation_callback=resolver_interpolation_callback,
#     761     memo=memo,
#     762 )
#     763 try:
# --> 764     return visitor.visit(parse_tree)
#     765 except InterpolationResolutionError:
#     766     raise
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:206, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 def accept(self, visitor:ParseTreeVisitor):
#     205     if hasattr( visitor, "visitConfigValue" ):
# --> 206         return visitor.visitConfigValue(self)
#     207     else:
#     208         return visitor.visitChildren(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:342, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     340 def accept(self, visitor:ParseTreeVisitor):
#     341     if hasattr( visitor, "visitText" ):
# --> 342         return visitor.visitText(self)
#     343     else:
#     344         return visitor.visitChildren(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar_visitor.py:301, in GrammarVisitor.visitText(self, ctx)
#     298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
# --> 301 return self._unescape(list(ctx.getChildren()))
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar_visitor.py:389, in GrammarVisitor._unescape(self, seq)
#     387     else:
#     388         assert isinstance(node, OmegaConfGrammarParser.InterpolationContext)
# --> 389         text = str(self.visitInterpolation(node))
#     390     chrs.append(text)
#     392 return "".join(chrs)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:921, in OmegaConfGrammarParser.InterpolationNodeContext.accept(self, visitor)
#     919 def accept(self, visitor:ParseTreeVisitor):
#     920     if hasattr( visitor, "visitInterpolationNode" ):
# --> 921         return visitor.visitInterpolationNode(self)
#     922     else:
#     923         return visitor.visitChildren(self)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/grammar_visitor.py:158, in GrammarVisitor.visitInterpolationNode(self, ctx)
#     155         inter_key_tokens.append(self.visitConfigKey(child))
#     157 inter_key = "".join(inter_key_tokens)
# --> 158 return self.node_interpolation_callback(inter_key, self.memo)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:745, in Container.resolve_parse_tree.<locals>.node_interpolation_callback(inter_key, memo)
#     742 def node_interpolation_callback(
#     743     inter_key: str, memo: Optional[Set[int]]
#     744 ) -> Optional["Node"]:
# --> 745     return self._resolve_node_interpolation(inter_key=inter_key, memo=memo)
#
# File ~/micromamba/envs/openff-env/lib/python3.11/site-packages/omegaconf/base.py:676, in Container._resolve_node_interpolation(self, inter_key, memo)
#     671     raise InterpolationToMissingValueError(
#     672         f"MissingMandatoryValue while resolving interpolation: {exc}"
#     673     ).with_traceback(sys.exc_info()[2])
#     675 if parent is None or value is None:
# --> 676     raise InterpolationKeyError(f"Interpolation key '{inter_key}' not found")
#     677 else:
#     678     self._validate_not_dereferencing_to_parent(node=self, target=value)
#
# InterpolationKeyError: Interpolation key 'data_dir' not found
#     full_key: data.input.inputs_dir
#     object_type=dict
