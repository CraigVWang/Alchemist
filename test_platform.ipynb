# %%
from alchemist import Alchemist

# %%
set_1_csv_path = "./dataset/FXR/FEP_set_1.csv"
set_2_csv_path = "./dataset/FXR/FEP_set_2.csv"
receptor_file_path = "./dataset/FXR/5q17.pdb"
alchemist = Alchemist(set_1_csv_path, receptor_file_path)
alchemist.run_preprocessor()
# Out:
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
#
# If you use Dimorphite-DL in your research, please cite:
# Ropp PJ, Kaminsky JC, Yablonski S, Durrant JD (2019) Dimorphite-DL: An
# open-source program for enumerating the ionization states of drug-like small
# molecules. J Cheminform 11:14. doi:10.1186/s13321-019-0336-9.
#
# 在pH 7.4下，共枚举到 1 种状态，选择第一个状态。
# Generating charges: 100%|██████████████████████| 15/15 [41:31<00:00, 166.11s/it]
# Mapping:   1%|          | 1/105 [01:31<2:39:14, 91.87s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       3 receptor_file_path = "./dataset/FXR/5q17.pdb"
#       4 alchemist = Alchemist(set_1_csv_path, receptor_file_path)
# ----> 5 alchemist.run_preprocessor()
#
# File /mnt/Workspace/Alchemist/alchemist.py:93, in run_preprocessor(self, rhfe_only)
#      91         f.write(ligand_network.to_graphml())
#      92 except Exception as e:
# ---> 93     print(f"写入ligand_network文件时出错: {e}")
#      95 # Define the ProteinComponent if not RHFE
#      96 if not rhfe_only:
#
# File ~/micromamba/envs/openfe/lib/python3.12/site-packages/gufe/components/proteincomponent.py:182, in ProteinComponent.from_pdb_file(cls, pdb_file, name)
#     166 """
#     167 Create ``ProteinComponent`` from PDB-formatted file.
#     168
#    (...)    179     the deserialized molecule
#     180 """
#     181 openmm_PDBFile = PDBFile(pdb_file)
# --> 182 return cls._from_openmmPDBFile(openmm_PDBFile=openmm_PDBFile, name=name)
#
# File ~/micromamba/envs/openfe/lib/python3.12/site-packages/gufe/components/proteincomponent.py:310, in ProteinComponent._from_openmmPDBFile(cls, openmm_PDBFile, name)
#     308 with rdBase.BlockLogs():  # turn off rdkit's verbose logging
#     309     try:
# --> 310         fc = _get_formal_charge(default_valence, connectivity, atom_name)
#     311         a.SetFormalCharge(fc)
#     312         a.UpdatePropertyCache(strict=True)
#
# File ~/micromamba/envs/openfe/lib/python3.12/site-packages/gufe/components/proteincomponent.py:293, in ProteinComponent._from_openmmPDBFile.<locals>._get_formal_charge(valence, connectivity, atom_name)
#     291 def _get_formal_charge(valence: int, connectivity: int, atom_name: str) -> int:
#     292     if connectivity == 0:  # ions
# --> 293         fc = _get_ion_charge(atom_name)
#     294     elif valence > connectivity:  # negative charge
#     295         fc = -(valence - connectivity)
#
# File ~/micromamba/envs/openfe/lib/python3.12/site-packages/gufe/components/proteincomponent.py:285, in ProteinComponent._from_openmmPDBFile.<locals>._get_ion_charge(ion_key)
#     283 res_n = a.GetMonomerInfo().GetResidueName()
#     284 res_ind = int(a.GetMonomerInfo().GetResidueNumber())
# --> 285 raise ValueError(f"Unknown ion: {ion_key} in residue {res_n} at index {res_ind}.")
#
# ValueError: Unknown ion: O in residue HOH at index 601.
